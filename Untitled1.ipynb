# %%
print('hello duy')
x=1
y=20
print(x+y)
# Out:
# hello duy
# 21

# %%
savings = 1000
factor = 1.10
desc = "Data Science"
year1 = savings * factor
print(type(year1))
doubledesc = desc * 2
print(doubledesc)
# Out:
# <class 'float'>
# Data ScienceData Science

# %%
savings = 1000
result = 1000 * 1.10 ** 15
print("tôi gửi ngân hàng $" + str(savings) + " , ssau 15 năm, bây giờ tôi đã có $" + str(result) + ". tuyệt vời ông mặt trời")
pi_string = "3.1415926"
pi_float = float(pi_string)
# Out:
# tôi gửi ngân hàng $1000 , ssau 15 năm, bây giờ tôi đã có $4177.248169415656. tuyệt vời ông mặt trời

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "livingroom", bed, "bathroom", bath]
print(areas)
# Out:
# [11.25, 18.0, 'livingroom', 10.75, 'bathroom', 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],
          ["kitchen", kit],
          ["livingroom", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['livingroom', 20.0]]
# <class 'list'>
